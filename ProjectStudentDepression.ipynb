# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Student Depression Dataset.csv")
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.drop(columns=['Work Pressure'], inplace=True)
df.drop(columns=['Study Satisfaction'], inplace=True)
df.drop(columns=['Job Satisfaction'], inplace=True)
df.drop(columns=['Have you ever had suicidal thoughts ?'], inplace=True)
df.drop(columns=['Family History of Mental Illness'], inplace=True)
df.drop(columns=['Financial Stress'], inplace=True)

# %%
df.drop(df.index[200:], inplace=True)

# %%
df.to_csv("updated_dataset.csv",index=False)

# %%
df
# Out:
#       id  Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0      2    Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1      8  Female  24.0      Bangalore    Student                2.0  5.90
# 2     26    Male  31.0       Srinagar    Student                3.0  7.03
# 3     30  Female  28.0       Varanasi    Student                3.0  5.59
# 4     32  Female  25.0         Jaipur    Student                4.0  8.13
# ..   ...     ...   ...            ...        ...                ...   ...
# 195  947    Male  33.0         Kanpur    Student                2.0  9.54
# 196  949  Female  20.0           Pune    Student                5.0  6.17
# 197  953  Female  25.0           Agra    Student                2.0  9.95
# 198  955    Male  24.0      Hyderabad    Student                5.0  9.05
# 199  956    Male  23.0           Agra    Student                4.0  9.24
#
#         Sleep Duration Dietary Habits    Degree  Work/Study Hours  Depression
# ...

# %%
#change Age to null in 2 rows where id is [2,5] 
df.loc[[2,5], 'Age'] = np.nan
df
# Out:
#       id  Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0      2    Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1      8  Female  24.0      Bangalore    Student                2.0  5.90
# 2     26    Male   NaN       Srinagar    Student                3.0  7.03
# 3     30  Female  28.0       Varanasi    Student                3.0  5.59
# 4     32  Female  25.0         Jaipur    Student                4.0  8.13
# ..   ...     ...   ...            ...        ...                ...   ...
# 195  947    Male  33.0         Kanpur    Student                2.0  9.54
# 196  949  Female  20.0           Pune    Student                5.0  6.17
# 197  953  Female  25.0           Agra    Student                2.0  9.95
# 198  955    Male  24.0      Hyderabad    Student                5.0  9.05
# 199  956    Male  23.0           Agra    Student                4.0  9.24
#
#         Sleep Duration Dietary Habits    Degree  Work/Study Hours  Depression
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# Gender               0
# Age                  2
# City                 0
# Profession           0
# Academic Pressure    0
# CGPA                 0
# Sleep Duration       0
# Dietary Habits       0
# Degree               0
# Work/Study Hours     0
# Depression           0
# dtype: int64

# %%
df["Age"] = df["Age"].ffill()
df
# Out:
#       id  Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0      2    Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1      8  Female  24.0      Bangalore    Student                2.0  5.90
# 2     26    Male  24.0       Srinagar    Student                3.0  7.03
# 3     30  Female  28.0       Varanasi    Student                3.0  5.59
# 4     32  Female  25.0         Jaipur    Student                4.0  8.13
# ..   ...     ...   ...            ...        ...                ...   ...
# 195  947    Male  33.0         Kanpur    Student                2.0  9.54
# 196  949  Female  20.0           Pune    Student                5.0  6.17
# 197  953  Female  25.0           Agra    Student                2.0  9.95
# 198  955    Male  24.0      Hyderabad    Student                5.0  9.05
# 199  956    Male  23.0           Agra    Student                4.0  9.24
#
#         Sleep Duration Dietary Habits    Degree  Work/Study Hours  Depression
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# Gender               0
# Age                  0
# City                 0
# Profession           0
# Academic Pressure    0
# CGPA                 0
# Sleep Duration       0
# Dietary Habits       0
# Degree               0
# Work/Study Hours     0
# Depression           0
# dtype: int64

# %%
print("\nData types before conversion:")
print(df.dtypes)
# Out:
# Data types before conversion:
# id                     int64
# Gender                object
# Age                  float64
# City                  object
# Profession            object
# Academic Pressure    float64
# CGPA                 float64
# Sleep Duration        object
# Dietary Habits        object
# Degree                object
# Work/Study Hours     float64
# Depression             int64
# dtype: object

# %%
#Display the first 10 rows of the dataset
df.head(10)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1   8  Female  24.0      Bangalore    Student                2.0  5.90
# 2  26    Male  24.0       Srinagar    Student                3.0  7.03
# 3  30  Female  28.0       Varanasi    Student                3.0  5.59
# 4  32  Female  25.0         Jaipur    Student                4.0  8.13
# 5  33    Male  25.0           Pune    Student                2.0  5.70
# 6  52    Male  30.0          Thane    Student                3.0  9.54
# 7  56  Female  30.0        Chennai    Student                2.0  8.04
# 8  59    Male  28.0         Nagpur    Student                3.0  9.79
# 9  62    Male  31.0         Nashik    Student                2.0  8.38
#
#       Sleep Duration Dietary Habits    Degree  Work/Study Hours  Depression
# 0          5-6 hours        Healthy   B.Pharm               3.0           1
# ...

# %%
#Show dataset info (.info()) and descriptive statistics (.describe()) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 200 non-null    int64
#  1   Gender             200 non-null    object
#  2   Age                200 non-null    float64
#  3   City               200 non-null    object
#  4   Profession         200 non-null    object
#  5   Academic Pressure  200 non-null    float64
#  6   CGPA               200 non-null    float64
#  7   Sleep Duration     200 non-null    object
#  8   Dietary Habits     200 non-null    object
#  9   Degree             200 non-null    object
#  10  Work/Study Hours   200 non-null    float64
#  11  Depression         200 non-null    int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#                id         Age  Academic Pressure       CGPA  Work/Study Hours  \
# count  200.000000  200.000000         200.000000  200.00000        200.000000
# mean   526.355000   25.505000           3.020000    7.63090          7.240000
# std    262.063495    4.895899           1.406946    1.49242          3.767409
# min      2.000000   18.000000           1.000000    5.11000          0.000000
# 25%    314.250000   21.000000           2.000000    6.16750          4.000000
# 50%    536.500000   25.000000           3.000000    7.86000          8.000000
# 75%    746.750000   30.000000           4.000000    8.94250         10.000000
# max    956.000000   34.000000           5.000000    9.96000         12.000000
#
#        Depression
# count  200.000000
# mean     0.565000
# std      0.497001
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
#Count unique values in categorical columns 
df["City"].unique()
# Out:
# array(['Visakhapatnam', 'Bangalore', 'Srinagar', 'Varanasi', 'Jaipur',
#        'Pune', 'Thane', 'Chennai', 'Nagpur', 'Nashik', 'Vadodara',
#        'Kalyan', 'Rajkot', 'Ahmedabad', 'Kolkata', 'Mumbai', 'Lucknow',
#        'Indore', 'Surat', 'Ludhiana', 'Bhopal', 'Meerut', 'Agra',
#        'Ghaziabad', 'Hyderabad', 'Vasai-Virar', 'Kanpur', 'Patna',
#        'Faridabad', 'Delhi'], dtype=object)

# %%
#Find averages, maximums, minimums of numeric columns

# %%
#Create a new column based on calculation (e.g., total score, percentage, revenue growth) 
#the average performance score of each student 

df["Average_Score"] = df[["CGPA"]].mean(axis=1)
df.head(10)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1   8  Female  24.0      Bangalore    Student                2.0  5.90
# 2  26    Male  24.0       Srinagar    Student                3.0  7.03
# 3  30  Female  28.0       Varanasi    Student                3.0  5.59
# 4  32  Female  25.0         Jaipur    Student                4.0  8.13
# 5  33    Male  25.0           Pune    Student                2.0  5.70
# 6  52    Male  30.0          Thane    Student                3.0  9.54
# 7  56  Female  30.0        Chennai    Student                2.0  8.04
# 8  59    Male  28.0         Nagpur    Student                3.0  9.79
# 9  62    Male  31.0         Nashik    Student                2.0  8.38
#
#       Sleep Duration Dietary Habits    Degree  Work/Study Hours  Depression  \
# 0          5-6 hours        Healthy   B.Pharm               3.0           1
# ...

# %%
# the maximum CGPA
max_CGPA = df["CGPA"].max()
print("The maximum CGPA:",max_CGPA)
# Out:
# The maximum CGPA: 9.96

# %%
higher_CGPA_Student = df[df["CGPA"] == df["CGPA"].max()]
higher_CGPA_Student
# Out:
#       id  Gender   Age  City Profession  Academic Pressure  CGPA  \
# 185  882  Female  29.0  Pune    Student                1.0  9.96
#
#         Sleep Duration Dietary Habits Degree  Work/Study Hours  Depression  \
# 185  Less than 5 hours        Healthy    LLM               6.0           0
#
#      Average_Score
# 185           9.96

# %%
# the minimum CGPA
min_CGPA = df["CGPA"].min()
min_CGPA
# Out:
# np.float64(5.11)

# %%
lowest_CGPA_Student = df[df["CGPA"] == df["CGPA"].min()]
lowest_CGPA_Student
# Out:
#       id Gender   Age     City Profession  Academic Pressure  CGPA  \
# 156  764   Male  20.0  Lucknow    Student                5.0  5.11
#
#         Sleep Duration Dietary Habits    Degree  Work/Study Hours  Depression  \
# 156  More than 8 hours      Unhealthy  Class 12              11.0           1
#
#      Average_Score
# 156           5.11

# %%
# using isin will return the student that are from "Delhi", "Hyderabad","Pune" only

df[df["City"].isin(["Delhi", "Hyderabad","Pune"])]
# Out:
#       id  Gender   Age       City Profession  Academic Pressure  CGPA  \
# 5     33    Male  25.0       Pune    Student                2.0  5.70
# 47   305  Female  30.0  Hyderabad    Student                1.0  5.86
# 54   335    Male  24.0  Hyderabad    Student                2.0  8.04
# 58   343    Male  23.0       Pune    Student                5.0  5.74
# 70   414    Male  33.0  Hyderabad    Student                5.0  7.94
# 87   491    Male  19.0       Pune    Student                3.0  9.05
# 88   494  Female  24.0  Hyderabad    Student                3.0  6.38
# 93   522    Male  22.0       Pune    Student                2.0  9.88
# 95   525  Female  34.0  Hyderabad    Student                3.0  5.32
# 99   535    Male  21.0      Delhi    Student                5.0  8.10
# 106  587  Female  33.0      Delhi    Student                2.0  5.51
# 110  595  Female  18.0      Delhi    Student                5.0  9.79
# ...

# %%
# look for first 3 student and their Academic Pressure
df.loc[:2,"Profession":"Academic Pressure"]
# Out:
#   Profession  Academic Pressure
# 0    Student                5.0
# 1    Student                2.0
# 2    Student                3.0

# %%
# age of student that are between 20,25
df[df["Age"].between(20,25)]
# Out:
#       id  Gender   Age       City Profession  Academic Pressure  CGPA  \
# 1      8  Female  24.0  Bangalore    Student                2.0  5.90
# 2     26    Male  24.0   Srinagar    Student                3.0  7.03
# 4     32  Female  25.0     Jaipur    Student                4.0  8.13
# 5     33    Male  25.0       Pune    Student                2.0  5.70
# 10    83    Male  24.0     Nagpur    Student                3.0  6.10
# ..   ...     ...   ...        ...        ...                ...   ...
# 190  918    Male  24.0    Kolkata    Student                3.0  9.44
# 196  949  Female  20.0       Pune    Student                5.0  6.17
# 197  953  Female  25.0       Agra    Student                2.0  9.95
# 198  955    Male  24.0  Hyderabad    Student                5.0  9.05
# 199  956    Male  23.0       Agra    Student                4.0  9.24
#
#         Sleep Duration Dietary Habits    Degree  Work/Study Hours  Depression  \
# ...

# %%
#return how muny students in each city
df.groupby("City").size()
# Out:
# City
# Agra              8
# Ahmedabad         7
# Bangalore         4
# Bhopal            8
# Chennai           4
# Delhi             4
# Faridabad         3
# Ghaziabad         6
# Hyderabad         8
# Indore            2
# Jaipur            8
# Kalyan           14
# Kanpur            4
# Kolkata          10
# Lucknow          11
# Ludhiana          7
# Meerut            4
# Mumbai            5
# Nagpur            5
# Nashik            7
# Patna             6
# Pune             10
# Rajkot            5
# Srinagar         11
# Surat             9
# Thane             9
# Vadodara          4
# Varanasi          4
# Vasai-Virar       8
# Visakhapatnam     5
# dtype: int64

# %%
# Determine which city’s students experience the most academic pressure
df.groupby("City")["Academic Pressure"].mean().sort_values(ascending=False)
# Out:
# City
# Bangalore        4.000000
# Ahmedabad        3.857143
# Delhi            3.750000
# Bhopal           3.750000
# Vasai-Virar      3.500000
# Nagpur           3.400000
# Rajkot           3.400000
# Lucknow          3.363636
# Faridabad        3.333333
# Mumbai           3.200000
# Hyderabad        3.125000
# Kalyan           3.071429
# Kolkata          3.000000
# Indore           3.000000
# Meerut           3.000000
# Patna            3.000000
# Ludhiana         3.000000
# Jaipur           2.875000
# Srinagar         2.818182
# Pune             2.800000
# Visakhapatnam    2.800000
# Varanasi         2.750000
# Nashik           2.714286
# Thane            2.666667
# Agra             2.625000
# Chennai          2.500000
# Kanpur           2.500000
# Ghaziabad        2.500000
# Vadodara         2.500000
# Surat            2.222222
# Name: Academic Pressure, dtype: float64

# %%
#5. Perform data visualization using matplotlib:

# %%
#Line plot: Show trend of one numeric variable over another (e.g., sales over months)
# line plot for Academic Pressure
df_sorted = df.sort_values(by="Age")
age_group = df_sorted.groupby("Age")["Depression"].mean().reset_index()
plt.plot(age_group["Age"], age_group["Depression"], marker = "o", linestyle="-", color='blue')

plt.title("Average Depression Level by Age")
plt.xlabel("Age")
plt.ylabel("Depression")
plt.grid(True)
plt.show()

# %%
# Bar chart: Compare numeric values across categories

# %%
#Bar plot for Sleep Duration & Academic Pressure
avg_pressure = df.groupby("Sleep Duration")["Academic Pressure"].mean()

plt.bar(avg_pressure.index, avg_pressure.values, color="skyblue", width=0.6)
plt.title("Average Academic Pressure by Sleep Duration Category")
plt.xlabel("Sleep Duration Category")
plt.ylabel("Average Academic Pressure")
plt.xticks(rotation=45)
plt.show()

# %%
#Histogram: Show distribution of a numeric variable

# %%
#“What are the CGPA values of students in each city?”
avg_cgpa = df.groupby("City")["CGPA"].mean().sort_values()

plt.barh(avg_cgpa.index, avg_cgpa.values, color="lightblue")
plt.title("Average CGPA by City")
plt.xlabel("Average CGPA")
plt.ylabel("City")
plt.show()

# %%
#Pie chart: Show proportion of categories

# %%
depression_rate = df.groupby("Gender")["Depression"].mean() * 100
plt.pie(depression_rate, 
        labels=depression_rate.index, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=["lightcoral", "lightskyblue"])
plt.title("Depression Percentage by Gender")
plt.show()

# %%
#Scatter plot: Show relationship between two numeric variables

# %%
#Scatter plate : Academic Pressure & Work/Study Hours	

plt.scatter(df["Academic Pressure"], df["Work/Study Hours"], color="blue", marker="o", alpha=0.3)
plt.title("Scatter Plot: Academic Pressure vs Work/Study Hours")
plt.xlabel("Academic Pressure")
plt.ylabel("Work/Study Hours")

plt.show()

# %%
#Box plot: Show spread and outliers for numeric columns

# %%
plt.boxplot(
    [df["Academic Pressure"], df["CGPA"], df["Work/Study Hours"]],
    tick_labels=["Academic Pressure", "CGPA", "Work/Study Hours"]
)
plt.show()

# %%
#Correlation heatmap: Show correlation between numeric columns

# %%
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Between numeric columns ")
plt.show()

# %%
# Calculate correlation matrix for numeric columns
corr = df.select_dtypes(include='number').corr()

# Extract the two most meaningful correlations
corr_age_depression = corr.loc["Age", "Depression"]
corr_pressure_depression = corr.loc["Academic Pressure", "Depression"]

# Print them nicely
print(f"Correlation between Age and Depression: {corr_age_depression:.2f}")
print(f"Correlation between Academic Pressure and Depression: {corr_pressure_depression:.2f}")
# Out:
# Correlation between Age and Depression: -0.26
# Correlation between Academic Pressure and Depression: 0.44

# %%
#6. Advanced tasks (challenge): 
#Combine multiple plots in one figure

# %%
#Compares two numeric variables (CGPA and Pressure) for each gender group side by side
grouped = df.groupby("Gender")[["CGPA", "Academic Pressure"]].mean()

grouped.plot(kind="bar", figsize=(6,5), color=["skyblue", "lightcoral"])
plt.title("Comparison of CGPA and Academic Pressure by Gender")
plt.ylabel("Average Value")
plt.xticks(rotation=0)
plt.show()

# %%
# Create figure with 2 subplots
fig, axs = plt.subplots(1, 2, figsize=(14,5))

# --------- Plot 1: Line plot (Average Depression by Degree) ---------
avg_hours_by_age = df.groupby("Degree")["Depression"].mean()
axs[0].plot(avg_hours_by_age.index, avg_hours_by_age.values, color="royalblue", marker='o', linewidth=2)
axs[0].set_title("Average Depression by Degree")
axs[0].set_xlabel("Degree")
axs[0].set_ylabel("Depression")
axs[0].grid(True, linestyle="--", alpha=0.5)

# --------- Plot 2: Bar chart (Sleep Duration by Dietary Habits) ---------
sleep_counts = df.groupby("Dietary Habits")["Sleep Duration"].value_counts().unstack().fillna(0)
sleep_counts.plot(kind="bar", ax=axs[1], stacked=True, colormap="Blues")
axs[1].set_title("Sleep Duration by Dietary Habits")
axs[1].set_xlabel("Dietary Habits")
axs[1].set_ylabel("Number of Students")
axs[1].legend(title="Sleep Duration", bbox_to_anchor=(1,1))

plt.tight_layout()
plt.show()
